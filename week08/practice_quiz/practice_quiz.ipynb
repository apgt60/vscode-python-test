# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, precision_score

df = pd.read_csv('data.csv')

# Write your code below

X = df.drop(['Target'],axis=1)
y = df['Target']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.20, random_state=42)

#base_estimator for bagging classifier is a decision tree by default
bagging_model=BaggingClassifier(random_state=1)
bagging_model.fit(X_train,y_train)

#Predicting on train and tests
y_pred_train = bagging_model.predict(X_train)

#Accuracy of the model
train_acc = bagging_model.score(X_train,y_train)
test_acc = bagging_model.score(X_test,y_test)

accuracy = accuracy_score(y_train,y_pred_train)
precision = precision_score(y_train,y_pred_train)

print(accuracy)
print(precision)
# Out:
# 1.0
# 0.0
# /opt/miniconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import BaggingClassifier
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns


df = pd.read_csv('data.csv')

# Write your code below
X = df.drop(['Target'],axis=1)
y = df['Target']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.30, random_state=42)

#base_estimator for bagging classifier is a decision tree by default
model=BaggingClassifier(random_state=42)
model.fit(X_train,y_train)

#Predicting on train and tests
y_pred = model.predict(X_test)

cm = confusion_matrix( y_test, y_pred, labels=[0, 1])
df_cm = pd.DataFrame(cm, index = [i for i in ["Actual - No","Actual - Yes"]],
                  columns = [i for i in ['Predicted - No','Predicted - Yes']])
group_counts = ["{0:0.0f}".format(value) for value in
            cm.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in
                        cm.flatten()/np.sum(cm)]
labels = [f"{v1}\n{v2}" for v1, v2 in
            zip(group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
plt.figure(figsize = (10,7))
sns.heatmap(df_cm, annot=labels,fmt='')
plt.ylabel('True label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 47.7222222222222, 'Predicted label')

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score

# Reading the dataset
df = pd.read_csv('data.csv')

X = df.drop(['Target'],axis=1)
y = df['Target']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.20, random_state=42)

#Train the random forest classifier
model = RandomForestClassifier(random_state=1)
model.fit(X_train,y_train)

y_pred_train = model.predict(X_train)

accuracy_train = accuracy_score(y_train,y_pred_train)
precision_train = precision_score(y_train,y_pred_train)

print(accuracy_score)
print(precision_score)
# Out:
# <function accuracy_score at 0x16c0a87c0>
# <function precision_score at 0x16c0a9760>
# /opt/miniconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score

# Reading the dataset
df = pd.read_csv('data2.csv')

X = df[['mpg','cylinders','displacement','horsepower','weight','acceleration','model year','origin']]
y = X['origin']
X.drop("origin" , inplace=True, axis=1)

#creditData=pd.get_dummies(creditData, columns=oneHotCols)
X_dummies = pd.get_dummies(X, columns=['model year'], dtype=float)

X_train, X_test, y_train, y_test = train_test_split(X_dummies, y, test_size=0.3, random_state=1)

#Train the random forest classifier
rforest = RandomForestClassifier(random_state=1)
rforest.fit(X_train,y_train)

y_pred_train = rforest.predict(X_train)
train_acc = accuracy_score(y_train,y_pred_train)

print(train_acc)
# Out:
# 1.0
# /var/folders/9g/c_7g81bx6qg5_smt2b4cjjb40000gn/T/ipykernel_3448/307561078.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X.drop("origin" , inplace=True, axis=1)

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score

# Reading the dataset
df = pd.read_csv('data2.csv')

X = df[['mpg','cylinders','displacement','horsepower','weight','acceleration','model year','origin']]
y = X['origin']
X.drop("origin" , inplace=True, axis=1)

#creditData=pd.get_dummies(creditData, columns=oneHotCols)
X_dummies = pd.get_dummies(X, columns=['model year'], dtype=float)

X_train, X_test, y_train, y_test = train_test_split(X_dummies, y, test_size=0.2, random_state=1)

#Train the random forest classifier
rforest = RandomForestClassifier(random_state=1)
rforest.fit(X_train,y_train)

y_pred_train = rforest.predict(X_train)
train_acc = accuracy_score(y_train,y_pred_train)

print(train_acc)

# %%
#Q6

# %%
#Q7

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score

# Reading the dataset
df = pd.read_csv('data2.csv')

X = df[['mpg','cylinders','displacement','horsepower','weight','acceleration','model year','origin']]
y = X['origin']
X.drop("origin" , inplace=True, axis=1)

#creditData=pd.get_dummies(creditData, columns=oneHotCols)
X_dummies = pd.get_dummies(X, columns=['model year'], dtype=float)

X_train, X_test, y_train, y_test = train_test_split(X_dummies, y, test_size=0.3, random_state=1)

#Train the random forest classifier
rforest = RandomForestClassifier(random_state=1, n_estimators=150)
rforest.fit(X_train,y_train)

y_pred_train = rforest.predict(X_train)
train_acc = accuracy_score(y_train,y_pred_train)

print(train_acc)
# Out:
# 1.0
# /var/folders/9g/c_7g81bx6qg5_smt2b4cjjb40000gn/T/ipykernel_3448/488722991.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X.drop("origin" , inplace=True, axis=1)

# %%
#Q8

# %%
#Q9
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score

# Reading the dataset
df = pd.read_csv('data2.csv')

features = df[['mpg','cylinders','displacement','horsepower','weight','acceleration','model year','origin']]
target = features['origin']
features.drop("origin" , inplace=True, axis=1)

features_encoded = pd.get_dummies(features, columns=['model year'], dtype=float)

X_train, X_test, y_train, y_test = train_test_split(features_encoded, target, test_size=0.3, random_state=1)

#Train the random forest classifier
rforest = RandomForestClassifier(random_state=1, min_samples_leaf=3)
rforest.fit(X_train,y_train)

y_pred_train = rforest.predict(X_train)
train_accuracy = accuracy_score(y_train,y_pred_train)
# Out:
# /var/folders/9g/c_7g81bx6qg5_smt2b4cjjb40000gn/T/ipykernel_3448/1068483065.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features.drop("origin" , inplace=True, axis=1)

# %%
#Q10
#Q11
#Q12
#Q13
