# %%
#use /opt/miniconda3/bin/pythgon
import pandas as pd
import io

df = pd.read_csv('data.csv')

s = io.StringIO()
df.to_csv(s, sep=',', index=False, header=True)
result_string = s.getvalue().strip() # .strip() removes trailing newline

print(result_string)
# Out:
# SepalLengthCm,SepalWidthCm,PetalLengthCm,PetalWidthCm,Species
# 5.1,3.5,1.4,0.2,0
# 4.9,3.0,1.4,0.2,0
# 4.7,3.2,1.3,0.2,0
# 4.6,3.1,1.5,0.2,0
# 5.0,3.6,1.4,0.2,0
# 5.4,3.9,1.7,0.4,0
# 4.6,3.4,1.4,0.3,0
# 5.0,3.4,1.5,0.2,0
# 4.4,2.9,1.4,0.2,0
# 4.9,3.1,1.5,0.1,0
# 5.4,3.7,1.5,0.2,0
# 4.8,3.4,1.6,0.2,0
# 4.8,3.0,1.4,0.1,0
# 4.3,3.0,1.1,0.1,0
# 5.8,4.0,1.2,0.2,0
# 5.7,4.4,1.5,0.4,0
# 5.4,3.9,1.3,0.4,0
# 5.1,3.5,1.4,0.3,0
# 5.7,3.8,1.7,0.3,0
# 5.1,3.8,1.5,0.3,0
# 5.4,3.4,1.7,0.2,0
# 5.1,3.7,1.5,0.4,0
# 4.6,3.6,1.0,0.2,0
# 5.1,3.3,1.7,0.5,0
# 4.8,3.4,1.9,0.2,0
# 5.0,3.0,1.6,0.2,0
# 5.0,3.4,1.6,0.4,0
# 5.2,3.5,1.5,0.2,0
# 5.2,3.4,1.4,0.2,0
# 4.7,3.2,1.6,0.2,0
# 4.8,3.1,1.6,0.2,0
# 5.4,3.4,1.5,0.4,0
# 5.2,4.1,1.5,0.1,0
# 5.5,4.2,1.4,0.2,0
# 4.9,3.1,1.5,0.1,0
# 5.0,3.2,1.2,0.2,0
# 5.5,3.5,1.3,0.2,0
# 4.9,3.1,1.5,0.1,0
# 4.4,3.0,1.3,0.2,0
# 5.1,3.4,1.5,0.2,0
# 5.0,3.5,1.3,0.3,0
# 4.5,2.3,1.3,0.3,0
# 4.4,3.2,1.3,0.2,0
# 5.0,3.5,1.6,0.6,0
# 5.1,3.8,1.9,0.4,0
# 4.8,3.0,1.4,0.3,0
# ...
